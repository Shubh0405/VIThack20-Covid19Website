# %% [markdown]
# <a href="https://colab.research.google.com/github/Shubh0405/VIThack20-Covid19Website/blob/Task4/Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns

# %%
df=pd.read_csv("covid19india.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27891 entries, 0 to 27890
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   patientId       27891 non-null  int64
#  1   reportedOn      27891 non-null  object
#  2   onsetEstimate   0 non-null      float64
#  3   ageEstimate     2346 non-null   object
#  4   gender          5313 non-null   object
#  5   city            2350 non-null   object
#  6   district        21051 non-null  object
#  7   state           27890 non-null  object
#  8   status          27891 non-null  object
#  9   notes           26555 non-null  object
#  10  contractedFrom  1638 non-null   object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 2.3+ MB

# %%
df.head()
# Out:
#    patientId  ... contractedFrom
# 0          1  ...            NaN
# 1          2  ...            NaN
# 2          3  ...            NaN
# 3          4  ...            NaN
# 4          5  ...            NaN
#
# [5 rows x 11 columns]

# %%
df['onsetEstimate'].value_counts().head()
# Out:
# Series([], Name: onsetEstimate, dtype: int64)

# %%
df['patientId'].value_counts()
# Out:
# 2047     1
# 3371     1
# 15629    1
# 9486     1
# 11535    1
#         ..
# 17053    1
# 23198    1
# 21151    1
# 10928    1
# 2049     1
# Name: patientId, Length: 27891, dtype: int64

# %%
df['ageEstimate'].value_counts()
# Out:
# 35     89
# 32     74
# 40     63
# 30     60
# 50     60
#        ..
# 92      1
# 98      1
# 88      1
# 1.5     1
# 0.3     1
# Name: ageEstimate, Length: 92, dtype: int64

# %%
df['gender'].value_counts()
# Out:
# male      3547
# female    1766
# Name: gender, dtype: int64

# %%
df.describe()
# Out:
#           patientId  onsetEstimate
# count  27891.000000            0.0
# mean   13946.000000            NaN
# std     8051.582515            NaN
# min        1.000000            NaN
# 25%     6973.500000            NaN
# 50%    13946.000000            NaN
# 75%    20918.500000            NaN
# max    27891.000000            NaN

# %%
df.isnull()
# Out:
#        patientId  reportedOn  onsetEstimate  ...  status  notes  contractedFrom
# 0          False       False           True  ...   False  False            True
# 1          False       False           True  ...   False  False            True
# 2          False       False           True  ...   False  False            True
# 3          False       False           True  ...   False  False            True
# 4          False       False           True  ...   False  False            True
# ...          ...         ...            ...  ...     ...    ...             ...
# 27886      False       False           True  ...   False  False            True
# 27887      False       False           True  ...   False  False            True
# 27888      False       False           True  ...   False  False            True
# 27889      False       False           True  ...   False  False            True
# 27890      False       False           True  ...   False  False            True
#
# [27891 rows x 11 columns]

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
df.drop('onsetEstimate',axis=1,inplace=True)
df.drop('contractedFrom',axis=1,inplace=True)

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# for col in df.columns:
#   df[col]=str(df[col])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27891 entries, 0 to 27890
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   patientId    27891 non-null  int64
#  1   reportedOn   27891 non-null  object
#  2   ageEstimate  2346 non-null   object
#  3   gender       5313 non-null   object
#  4   city         2350 non-null   object
#  5   district     21051 non-null  object
#  6   state        27890 non-null  object
#  7   status       27891 non-null  object
#  8   notes        26555 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 1.9+ MB

# %%
# LabEn=LabelEncoder();
# for col in df.columns:
#     df[col] = LabEn.fit_transform(df[col])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27891 entries, 0 to 27890
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   patientId    27891 non-null  int64
#  1   reportedOn   27891 non-null  object
#  2   ageEstimate  2346 non-null   object
#  3   gender       5313 non-null   object
#  4   city         2350 non-null   object
#  5   district     21051 non-null  object
#  6   state        27890 non-null  object
#  7   status       27891 non-null  object
#  8   notes        26555 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 1.9+ MB

# %%
df.head(50)
# Out:
#     patientId  ...                                              notes
# 0           1  ...                               Travelled from Wuhan
# 1           2  ...                               Travelled from Wuhan
# 2           3  ...                               Travelled from Wuhan
# 3           4  ...                      Travelled from Austria, Italy
# 4           5  ...  Travelled from Dubai to Bangalore on 20th Feb,...
# 5           6  ...                               Travelled from Italy
# 6           7  ...                               Travelled from Italy
# 7           8  ...                               Travelled from Italy
# 8           9  ...                               Travelled from Italy
# 9          10  ...                               Travelled from Italy
# 10         11  ...                               Travelled from Italy
# 11         12  ...                               Travelled from Italy
# 12         13  ...                               Travelled from Italy
# 13         14  ...                               Travelled from Italy
# 14         15  ...                               Travelled from Italy
# 15         16  ...                               Travelled from Italy
# 16         17  ...                               Travelled from Italy
# 17         18  ...                               Travelled from Italy
# 18         19  ...                               Travelled from Italy
# 19         20  ...                               Travelled from Italy
# 20         21  ...                   Travelled from Italy, Wife of P6
# 21         22  ...                               Family members of P4
# 22         23  ...                               Family members of P4
# 23         24  ...                               Family members of P4
# 24         25  ...                               Family members of P4
# 25         26  ...                               Family members of P4
# 26         27  ...                               Family members of P4
# 27         28  ...  Accompanied the Italian tourists, Nationality:...
# 28         29  ...                   Travelled from Italy PayTm Emp,
# 29         30  ...                                Travelled from Iran
# 30         31  ...               Travelled from Thailand and Malaysia
# 31         32  ...                                Travelled from Iran
# 32         33  ...                                                NaN
# 33         34  ...  Travelled from Oman to Chennai Airport on 28.0...
# 34         35  ...    Travelled from Italy on 29/02/2020 through Doha
# 35         36  ...    Travelled from Italy on 29/02/2020 through Doha
# 36         37  ...    Travelled from Italy on 29/02/2020 through Doha
# 37         38  ...                  Relative and neighbour of P35-P37
# 38         39  ...                 Relative  and neighbour of P35-P37
# 39         40  ...                                  No travel history
# 40         41  ...                                Travelled from Iran
# 41         42  ...    Travelled from US via London, Mindtree Employee
# 42         43  ...  Travelled from Italy on 07/03/2020 (Parents in...
# 43         44  ...    Travelled from Dubai on 1 March, Husband of P45
# 44         45  ...       Travelled from Dubai on 1 March, Wife of P44
# 45         46  ...                               Travelled from Italy
# 46         47  ...  Factory Manager contact with businessman from ...
# 47         48  ...                        Was in contact with P22-P27
# 48         49  ...                           Friends of P35, P36, P37
# 49         50  ...                           Friends of P35, P36, P37
#
# [50 rows x 9 columns]

# %%
# df.isnull().values()

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1028 entries, 0 to 26766
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   patientId    1028 non-null   int64
#  1   reportedOn   1028 non-null   object
#  2   ageEstimate  1028 non-null   object
#  3   gender       1028 non-null   object
#  4   city         1028 non-null   object
#  5   district     1028 non-null   object
#  6   state        1028 non-null   object
#  7   status       1028 non-null   object
#  8   notes        1028 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 80.3+ KB

# %%
df
# Out:
#        patientId  ...                                              notes
# 0              1  ...                               Travelled from Wuhan
# 3              4  ...                      Travelled from Austria, Italy
# 4              5  ...  Travelled from Dubai to Bangalore on 20th Feb,...
# 5              6  ...                               Travelled from Italy
# 20            21  ...                   Travelled from Italy, Wife of P6
# ...          ...  ...                                                ...
# 26481      26482  ...                                    Details awaited
# 26482      26483  ...                                    Details awaited
# 26483      26484  ...                                    Details awaited
# 26765      26766  ...                                    Details awaited
# 26766      26767  ...                                    Details awaited
#
# [1028 rows x 9 columns]

# %%
# df.ageEstimate = pd.Categorical(df.ageEstimate)

# %%
# df['ageEstimate'] = df.ageEstimate.cat.codes

# %%
df.gender = pd.Categorical(df.gender)
df['gender'] = df.gender.cat.codes

# %%
df.city = pd.Categorical(df.city)
df['city'] = df.city.cat.codes

df.district = pd.Categorical(df.district)
df['district'] = df.district.cat.codes

df.state = pd.Categorical(df.state)
df['state'] = df.state.cat.codes


df.status = pd.Categorical(df.status)
df['status'] = df.status.cat.codes

# %%
df
# Out:
#        patientId  ...                                              notes
# 0              1  ...                               Travelled from Wuhan
# 3              4  ...                      Travelled from Austria, Italy
# 4              5  ...  Travelled from Dubai to Bangalore on 20th Feb,...
# 5              6  ...                               Travelled from Italy
# 20            21  ...                   Travelled from Italy, Wife of P6
# ...          ...  ...                                                ...
# 26481      26482  ...                                    Details awaited
# 26482      26483  ...                                    Details awaited
# 26483      26484  ...                                    Details awaited
# 26765      26766  ...                                    Details awaited
# 26766      26767  ...                                    Details awaited
#
# [1028 rows x 9 columns]
